# %% [markdown]
# # **Lab 4.2 NN MLP and CNN**

# %%
# %pip install tensorboard
# %pip install tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.cuda.amp import autocast, GradScaler
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader,Subset
from torch.utils.tensorboard import SummaryWriter
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\pc\appdata\local\programs\python\python313\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\pc\appdata\roaming\python\python313\site-packages (from tqdm) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/attr_value.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/resource_handle.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_shape.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/types.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/full_type.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/function.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/node_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/op_def.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/graph_debug_info.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/versions.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at xla/tsl/protobuf/coordination_config.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/cost_graph.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/step_stats.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/allocation_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/framework/tensor_description.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/cluster.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(
# c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\protobuf\runtime_version.py:98: UserWarning: Protobuf gencode version 5.28.3 is exactly one major version older than the runtime version 6.31.1 at tensorflow/core/protobuf/debug.proto. Please update the gencode to avoid compatibility violations in the next runtime release.
#   warnings.warn(

# %% [markdown]
# Complete the `load_data()` function that loads the image using `ImageFolder()` with the specific `transforms.compose()` provided below.
# `load_data()` will return `DataLoader()` and print the information about the Dataset.
# This function must load only a pair of classes from the entire dataset.
# Please ensure that the final image is in grayscale and has a size of 28x28.
#
# `transforms.Compose()` :
# - `transforms.Resize(32)`
# - `transforms.ToTensor()`
# - `transforms.Pad()`
# - `transforms.RandomRotation(45),`
# - `transforms.CenterCrop(28)`
#
# Resource : [`transforms.Compose()`](https://pytorch.org/vision/main/generated/torchvision.transforms.Compose.html#compose), [`torchvision.transforms v1`](<https://pytorch.org/vision/stable/transforms.html#v1-api-reference:~:text=custom)%20tv_tensor%20type.-,V1%20API%20Reference,-Geometry>)

# %%
def load_data(path, class_names):
    ### START CODE HERE ###
    transform = transforms.Compose(
        [
            transforms.Resize((32, 32)),
            transforms.ToTensor(),
            transforms.Pad(10),
            transforms.RandomRotation(45),
            transforms.CenterCrop(28),
            transforms.Grayscale(num_output_channels=1),
        ]
    )

    dataset = ImageFolder(path, transform=transform)

    # filter dataset by class names
    filtered_indices = [
        i
        for i, (_, label) in enumerate(dataset)
        if dataset.classes[label] in class_names
    ]
    filtered_dataset = Subset(dataset, filtered_indices)

    train_size = int(0.8 * len(filtered_dataset))
    test_size = len(filtered_dataset) - train_size
    train_dataset, test_dataset = torch.utils.data.random_split(
        filtered_dataset, [train_size, test_size]
    )

    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

    ### END CODE HERE ###

    return train_loader, test_loader

# %% [markdown]
# Use your `load_data()` function to load the dataset in the cell below. Then, display the image from the first batch.
#
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ```
# 📃Train Dataset:
# 	Number of images in class 0: 313
# 	Number of images in class 1: 308
# 	Number of training samples: 621
#
# 📃Test Dataset:
# 	Number of images in class 0: 75
# 	Number of images in class 1: 81
# 	Number of testing samples: 156
# ```
#
#
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/03.png?raw=true)
#
# </details>

# %%
def show_first_batch_image(data_loader):
    images, labels = next(iter(data_loader))

    images = images[:16]

    fig, axs = plt.subplots(4, 4, figsize=(6, 6))
    for i in range(len(images)):
        axs[i // 4, i % 4].imshow(images[i].squeeze(0), cmap='gray')
        axs[i // 4, i % 4].set_title(f"Label: {labels[i].item()}")
        axs[i // 4, i % 4].axis("off")
    plt.tight_layout()
    plt.show()

# %%
### START CODE HERE ###
class_names = ["0", "1"]
train_loader, test_loader = load_data(
    "thai-handwriting-number.appspot.com", class_names
)

show_first_batch_image(train_loader)
### END CODE HERE ###

# %% [markdown]
# **Create Models**
# 1. **NN (Neural Network)**:
# - **Input**: 28x28 grayscale images (1 channel)
# - **Architecture**: Single fully connected layer with sigmoid activation
# - **Output**: Single neuron output with sigmoid activation
# - **Description**: This is a simple feedforward neural network with a single fully connected layer. It takes input images, flattens them, passes through a fully connected layer, and applies sigmoid activation to produce the output.
#
# 2. **MLP (Multi-Layer Perceptron)**:
# - **Input**: 28x28 grayscale images (1 channel)
# - **Architecture**: Two fully connected layers with sigmoid activations
# - **Output**: Single neuron output with sigmoid activation
# - **Description**: This is a multi-layer perceptron with two fully connected layers. After flattening the input images, it passes through the first fully connected layer with sigmoid activation, followed by the second fully connected layer with sigmoid activation, producing the output.
#
# 3. **CNN (Convolutional Neural Network)**:
# - **Input**: 28x28 grayscale images (1 channel)
# - **Architecture**: Two convolutional layers with ReLU activations, followed by two fully connected layers with ReLU activations
# - **Output**: Single neuron output with sigmoid activation
# - **Description**: This is a convolutional neural network with two convolutional layers followed by two fully connected layers. It applies convolutional operations with ReLU activations, followed by flattening the output and passing through fully connected layers with ReLU activations. Finally, it produces a single neuron output with sigmoid activation.
#
#
# Every model should have a `get_features()` method that returns the result from all layers.

# %%
### START CODE HERE ###
class NN(nn.Module):
    def __init__(self):
        super(NN, self).__init__()
        self.fc = nn.Linear(28 * 28, 1)
        self.activation = nn.Sigmoid()

    def get_features(self, x):
        x = x.view(x.size(0), -1)
        out = self.fc(x)
        return self.activation(out)

    def forward(self, x):
        return self.get_features(x)


class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(28 * 28, 128)
        self.fc2 = nn.Linear(128, 1)
        self.activation = nn.Sigmoid()

    def get_features(self, x):
        x = x.view(x.size(0), -1)  # Flatten the input
        x_out = self.activation(self.fc1(x))
        out = self.fc2(x_out)
        return self.activation(out)

    def forward(self, x):
        return self.get_features(x)


class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 16, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(16, 32, kernel_size=3, padding=1)
        self.fc1 = nn.Linear(32 * 28 * 28, 128)
        self.fc2 = nn.Linear(128, 1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()

    def get_features(self, x):
        x = self.relu(self.conv1(x))
        x = self.relu(self.conv2(x))
        x = x.view(x.size(0), -1)
        x = self.relu(self.fc1(x))
        out = self.fc2(x)
        return self.sigmoid(out)

    def forward(self, x):
        return self.get_features(x)


### END CODE HERE ###

# %% [markdown]
# Complete the function below. This function will be used to display the feature map from the models at every epoch on TensorBoard.
#
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output that will be display on TensorBoard</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
# - `NN()`<br>
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/04.png?raw=true)
# - `MLP()`<br>
# ![image-2.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/05.png?raw=true)
# - `CNN()`<br>
# ![image-3.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/06.png?raw=true)
# </details>

# %%
def show_featuremaps(features):
    feats = features.detach().cpu().numpy().squeeze()
    batch_size = feats.shape[0] if len(feats.shape) > 0 else 1

    fig, axs = plt.subplots(figsize=(10, 10))
    axs.bar(np.arange(batch_size), feats, color="blue")
    axs.set_xlabel("Batch Index")
    axs.set_ylabel("Feature Value")
    axs.set_ylim(0, 1)
    axs.set_title("Feature Map Values")

    return fig

# %% [markdown]
# TensorBoard 101
#
# Complete the `train()` function in the cell below. This function should evaluate the model at every epoch, log the training loss/accuracy, test loss/accuracy, and display the feature map from all layers of the model at every epoch on TensorBoard. Additionally, it should save the model at the last epoch.
#
# Resource : [PyTorch Training loop](<https://pytorch.org/tutorials/beginner/introyt/trainingyt.html#:~:text=%3D0.9)-,The%20Training%20Loop,-Below%2C%20we%20have>), [TensorBoard](https://pytorch.org/docs/stable/tensorboard.html)
#
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output that will be display on TensorBoard</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
#
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/07.png?raw=true)
#
# ![image-2.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/08.png?raw=true)
# </details>

# %%
def train(
    class_names,
    model,
    opt,
    loss_fn,
    train_loader,
    test_loader,
    epochs=5,
    writer=None,
    checkpoint_path=None,
    device="cpu",
):
    ### START CODE HERE ###

    model.to(device)

    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        correct = 0
        total = 0

        for inputs, labels in tqdm(train_loader, desc=f"Epoch {epoch + 1}/{epochs}"):
            inputs = inputs.to(device)
            labels = labels.to(device)
            
            # Fix: Map labels to binary (0, 1)
            # Convert labels to binary: min class -> 0, max class -> 1
            unique_labels = torch.unique(labels)
            min_label = unique_labels.min()
            max_label = unique_labels.max()
            
            # Map: min_label -> 0, max_label -> 1
            binary_labels = (labels == max_label).float().unsqueeze(1)

            opt.zero_grad()
            outputs = model(inputs)
            loss = loss_fn(outputs, binary_labels)
            loss.backward()
            opt.step()

            train_loss += loss.item() * inputs.size(0)
            predictions = (outputs > 0.5).float()
            correct += (predictions == binary_labels).sum().item()
            total += binary_labels.size(0)

        avg_loss = train_loss / len(train_loader.dataset)
        train_accuracy = correct / total

        model.eval()
        test_loss = 0.0
        correct = 0
        total = 0

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                # Fix: Map labels to binary (0, 1) for test set too
                unique_labels = torch.unique(labels)
                min_label = unique_labels.min()
                max_label = unique_labels.max()
                
                # Map: min_label -> 0, max_label -> 1
                binary_labels = (labels == max_label).float().unsqueeze(1)
                
                outputs = model(inputs)
                loss = loss_fn(outputs, binary_labels)
                test_loss += loss.item() * inputs.size(0)
                
                predictions = (outputs > 0.5).float()
                correct += (predictions == binary_labels).sum().item()
                total += binary_labels.size(0)

        avg_test_loss = test_loss / len(test_loader.dataset)
        test_accuracy = correct / total

        if writer:
            writer.add_scalar("Loss/train", avg_loss, epoch)
            writer.add_scalar("Loss/test", avg_test_loss, epoch)
            writer.add_scalar("Accuracy/train", train_accuracy, epoch)
            writer.add_scalar("Accuracy/test", test_accuracy, epoch)

            try:
                if hasattr(model, "get_features"):
                    features = model.get_features(inputs)
                    fig = show_featuremaps(features)
                    writer.add_figure("Feature Maps", fig, epoch)
                    plt.close(fig)
            except Exception as e:
                print(f"Error in feature visualization: {e}")

        print(
            f"Epoch {epoch + 1}/{epochs}, Train Loss: {avg_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}"
        )

    if checkpoint_path:
        import os
        os.makedirs(os.path.dirname(checkpoint_path), exist_ok=True)
        torch.save(model.state_dict(), checkpoint_path)
        print(f"Model saved to {checkpoint_path}")
    ### END CODE HERE ###

# %% [markdown]
# Use your `train()` function to train all types of models with all combinations of numbers that you've obtained.

# %%
### START CODE HERE ###
from itertools import combinations

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

models = {"nn": NN(), "mlp": MLP(), "cnn": CNN()}


pair_digit = list(combinations(range(10), 2))

for class1, class2 in pair_digit:
    print(f"Training model for pair: {class1} vs {class2}")

    class_names = [str(class1), str(class2)]
    train_loader, test_loader = load_data(
        "thai-handwriting-number.appspot.com", class_names
    )

    for name, model_instance in models.items():
        print(f"Training {name} model...")
        opt = torch.optim.Adam(model_instance.parameters(), lr=0.001)
        writer = SummaryWriter(log_dir=f"./runs/{name}_{class1}_vs_{class2}")
        model = model_instance.to(device)

        train(
            class_names,
            model,
            opt,
            loss_fn=nn.BCELoss(),
            train_loader=train_loader,
            test_loader=test_loader,
            epochs=10,
            writer=writer,
            checkpoint_path=f"./checkpoints/{name}_{class1}_vs_{class2}.pth",
            device=device,
        )

        writer.close()
### END CODE HERE ###
# Out:
# Training model for pair: 0 vs 1
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 28.34it/s]
# Epoch 1/10, Train Loss: 0.7082, Train Accuracy: 0.5185, Test Loss: 0.7023, Test Accuracy: 0.5321
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.14it/s]
# Epoch 2/10, Train Loss: 0.6824, Train Accuracy: 0.5636, Test Loss: 0.6668, Test Accuracy: 0.6538
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 29.26it/s]
# Epoch 3/10, Train Loss: 0.6616, Train Accuracy: 0.5942, Test Loss: 0.6581, Test Accuracy: 0.5513
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 29.24it/s]
# Epoch 4/10, Train Loss: 0.6501, Train Accuracy: 0.5797, Test Loss: 0.6472, Test Accuracy: 0.6474
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 25.60it/s]
# Epoch 5/10, Train Loss: 0.6372, Train Accuracy: 0.6329, Test Loss: 0.6233, Test Accuracy: 0.7308
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 25.94it/s]
# Epoch 6/10, Train Loss: 0.6225, Train Accuracy: 0.6570, Test Loss: 0.6125, Test Accuracy: 0.6795
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 28.53it/s]
# Epoch 7/10, Train Loss: 0.6041, Train Accuracy: 0.7198, Test Loss: 0.6197, Test Accuracy: 0.6603
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 24.79it/s]
# Epoch 8/10, Train Loss: 0.5931, Train Accuracy: 0.7295, Test Loss: 0.6032, Test Accuracy: 0.6987
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 25.74it/s]
# Epoch 9/10, Train Loss: 0.5664, Train Accuracy: 0.7424, Test Loss: 0.6591, Test Accuracy: 0.6282
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 28.23it/s]
# Epoch 10/10, Train Loss: 0.5761, Train Accuracy: 0.7230, Test Loss: 0.5938, Test Accuracy: 0.7115
# Model saved to ./checkpoints/nn_0_vs_1.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 27.16it/s]
# Epoch 1/10, Train Loss: 0.7200, Train Accuracy: 0.5089, Test Loss: 0.7078, Test Accuracy: 0.4679
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.07it/s]
# Epoch 2/10, Train Loss: 0.6815, Train Accuracy: 0.5314, Test Loss: 0.6953, Test Accuracy: 0.4679
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 27.07it/s]
# Epoch 3/10, Train Loss: 0.6702, Train Accuracy: 0.5572, Test Loss: 0.6549, Test Accuracy: 0.7244
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 27.08it/s]
# Epoch 4/10, Train Loss: 0.6328, Train Accuracy: 0.6989, Test Loss: 0.6287, Test Accuracy: 0.7179
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 26.93it/s]
# Epoch 5/10, Train Loss: 0.6111, Train Accuracy: 0.7134, Test Loss: 0.5985, Test Accuracy: 0.7372
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 27.43it/s]
# Epoch 6/10, Train Loss: 0.5921, Train Accuracy: 0.7214, Test Loss: 0.5791, Test Accuracy: 0.7564
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 28.13it/s]
# Epoch 7/10, Train Loss: 0.5641, Train Accuracy: 0.7295, Test Loss: 0.5896, Test Accuracy: 0.6731
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 27.64it/s]
# Epoch 8/10, Train Loss: 0.5602, Train Accuracy: 0.7536, Test Loss: 0.5655, Test Accuracy: 0.7244
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 27.39it/s]
# Epoch 9/10, Train Loss: 0.5334, Train Accuracy: 0.7472, Test Loss: 0.5471, Test Accuracy: 0.7628
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 25.61it/s]
# Epoch 10/10, Train Loss: 0.5252, Train Accuracy: 0.7617, Test Loss: 0.5540, Test Accuracy: 0.7308
# Model saved to ./checkpoints/mlp_0_vs_1.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 20.35it/s]
# Epoch 1/10, Train Loss: 0.7126, Train Accuracy: 0.5314, Test Loss: 0.6867, Test Accuracy: 0.6923
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 20.36it/s]
# Epoch 2/10, Train Loss: 0.6449, Train Accuracy: 0.6908, Test Loss: 0.6135, Test Accuracy: 0.6731
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 19.44it/s]
# Epoch 3/10, Train Loss: 0.4954, Train Accuracy: 0.7665, Test Loss: 0.5233, Test Accuracy: 0.7372
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 20.03it/s]
# Epoch 4/10, Train Loss: 0.4762, Train Accuracy: 0.7729, Test Loss: 0.5268, Test Accuracy: 0.7308
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 18.18it/s]
# Epoch 5/10, Train Loss: 0.4106, Train Accuracy: 0.8132, Test Loss: 0.5294, Test Accuracy: 0.7564
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 17.96it/s]
# Epoch 6/10, Train Loss: 0.3613, Train Accuracy: 0.8454, Test Loss: 0.4787, Test Accuracy: 0.7692
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 18.41it/s]
# Epoch 7/10, Train Loss: 0.3314, Train Accuracy: 0.8712, Test Loss: 0.4348, Test Accuracy: 0.8205
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 16.67it/s]
# Epoch 8/10, Train Loss: 0.2918, Train Accuracy: 0.8857, Test Loss: 0.4513, Test Accuracy: 0.8141
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 18.02it/s]
# Epoch 9/10, Train Loss: 0.3066, Train Accuracy: 0.8808, Test Loss: 0.3889, Test Accuracy: 0.8654
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 17.44it/s]
# Epoch 10/10, Train Loss: 0.2930, Train Accuracy: 0.8776, Test Loss: 0.3766, Test Accuracy: 0.8269
# Model saved to ./checkpoints/cnn_0_vs_1.pth
# Training model for pair: 0 vs 2
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 28.03it/s]
# Epoch 1/10, Train Loss: 0.5969, Train Accuracy: 0.7021, Test Loss: 0.5472, Test Accuracy: 0.7500
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.87it/s]
# Epoch 2/10, Train Loss: 0.6096, Train Accuracy: 0.6667, Test Loss: 0.5659, Test Accuracy: 0.7564
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 28.83it/s]
# Epoch 3/10, Train Loss: 0.5706, Train Accuracy: 0.7279, Test Loss: 0.5286, Test Accuracy: 0.8013
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 26.73it/s]
# Epoch 4/10, Train Loss: 0.5703, Train Accuracy: 0.7295, Test Loss: 0.5590, Test Accuracy: 0.7500
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 29.35it/s]
# Epoch 5/10, Train Loss: 0.5574, Train Accuracy: 0.7407, Test Loss: 0.5607, Test Accuracy: 0.7436
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 29.55it/s]
# Epoch 6/10, Train Loss: 0.5451, Train Accuracy: 0.7601, Test Loss: 0.5958, Test Accuracy: 0.6282
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 29.03it/s]
# Epoch 7/10, Train Loss: 0.5404, Train Accuracy: 0.7488, Test Loss: 0.5675, Test Accuracy: 0.6859
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 28.84it/s]
# Epoch 8/10, Train Loss: 0.5434, Train Accuracy: 0.7456, Test Loss: 0.5208, Test Accuracy: 0.7500
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 29.26it/s]
# Epoch 9/10, Train Loss: 0.5146, Train Accuracy: 0.7890, Test Loss: 0.4785, Test Accuracy: 0.8141
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 28.34it/s]
# Epoch 10/10, Train Loss: 0.5091, Train Accuracy: 0.7939, Test Loss: 0.4986, Test Accuracy: 0.7692
# Model saved to ./checkpoints/nn_0_vs_2.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 26.35it/s]
# Epoch 1/10, Train Loss: 0.5681, Train Accuracy: 0.7198, Test Loss: 0.5349, Test Accuracy: 0.7372
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.10it/s]
# Epoch 2/10, Train Loss: 0.5301, Train Accuracy: 0.7585, Test Loss: 0.5159, Test Accuracy: 0.7692
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 27.57it/s]
# Epoch 3/10, Train Loss: 0.5166, Train Accuracy: 0.7729, Test Loss: 0.4589, Test Accuracy: 0.8013
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 27.22it/s]
# Epoch 4/10, Train Loss: 0.4966, Train Accuracy: 0.8052, Test Loss: 0.5026, Test Accuracy: 0.7308
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 28.00it/s]
# Epoch 5/10, Train Loss: 0.4975, Train Accuracy: 0.7858, Test Loss: 0.4728, Test Accuracy: 0.8077
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 27.43it/s]
# Epoch 6/10, Train Loss: 0.4874, Train Accuracy: 0.8148, Test Loss: 0.4364, Test Accuracy: 0.8462
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 26.36it/s]
# Epoch 7/10, Train Loss: 0.4837, Train Accuracy: 0.7987, Test Loss: 0.4543, Test Accuracy: 0.8077
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 27.52it/s]
# Epoch 8/10, Train Loss: 0.4520, Train Accuracy: 0.8277, Test Loss: 0.4251, Test Accuracy: 0.8333
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 27.00it/s]
# Epoch 9/10, Train Loss: 0.4673, Train Accuracy: 0.8068, Test Loss: 0.4667, Test Accuracy: 0.7756
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 25.52it/s]
# Epoch 10/10, Train Loss: 0.4619, Train Accuracy: 0.8132, Test Loss: 0.3749, Test Accuracy: 0.8718
# Model saved to ./checkpoints/mlp_0_vs_2.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 18.27it/s]
# Epoch 1/10, Train Loss: 0.3996, Train Accuracy: 0.8519, Test Loss: 0.3251, Test Accuracy: 0.8910
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 16.36it/s]
# Epoch 2/10, Train Loss: 0.3066, Train Accuracy: 0.8873, Test Loss: 0.2295, Test Accuracy: 0.9167
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 17.32it/s]
# Epoch 3/10, Train Loss: 0.2962, Train Accuracy: 0.8776, Test Loss: 0.2561, Test Accuracy: 0.9231
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 18.21it/s]
# Epoch 4/10, Train Loss: 0.2568, Train Accuracy: 0.9114, Test Loss: 0.1871, Test Accuracy: 0.9487
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 18.18it/s]
# Epoch 5/10, Train Loss: 0.2350, Train Accuracy: 0.9034, Test Loss: 0.2112, Test Accuracy: 0.9167
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 19.42it/s]
# Epoch 6/10, Train Loss: 0.2171, Train Accuracy: 0.9179, Test Loss: 0.2296, Test Accuracy: 0.9167
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 20.82it/s]
# Epoch 7/10, Train Loss: 0.1949, Train Accuracy: 0.9243, Test Loss: 0.2020, Test Accuracy: 0.9359
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 19.33it/s]
# Epoch 8/10, Train Loss: 0.2003, Train Accuracy: 0.9211, Test Loss: 0.1710, Test Accuracy: 0.9359
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 19.14it/s]
# Epoch 9/10, Train Loss: 0.1716, Train Accuracy: 0.9275, Test Loss: 0.1849, Test Accuracy: 0.9359
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 19.13it/s]
# Epoch 10/10, Train Loss: 0.1609, Train Accuracy: 0.9308, Test Loss: 0.1635, Test Accuracy: 0.9359
# Model saved to ./checkpoints/cnn_0_vs_2.pth
# Training model for pair: 0 vs 3
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 29.38it/s]
# Epoch 1/10, Train Loss: 0.5872, Train Accuracy: 0.7016, Test Loss: 0.5858, Test Accuracy: 0.7500
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.86it/s]
# Epoch 2/10, Train Loss: 0.5469, Train Accuracy: 0.7403, Test Loss: 0.6249, Test Accuracy: 0.6795
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 29.57it/s]
# Epoch 3/10, Train Loss: 0.5451, Train Accuracy: 0.7710, Test Loss: 0.5435, Test Accuracy: 0.7756
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 28.72it/s]
# Epoch 4/10, Train Loss: 0.5283, Train Accuracy: 0.7742, Test Loss: 0.5403, Test Accuracy: 0.7564
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 29.02it/s]
# Epoch 5/10, Train Loss: 0.5341, Train Accuracy: 0.7903, Test Loss: 0.5640, Test Accuracy: 0.7372
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 29.13it/s]
# Epoch 6/10, Train Loss: 0.5142, Train Accuracy: 0.8032, Test Loss: 0.5417, Test Accuracy: 0.7821
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 28.81it/s]
# Epoch 7/10, Train Loss: 0.5081, Train Accuracy: 0.7839, Test Loss: 0.6017, Test Accuracy: 0.7244
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 29.13it/s]
# Epoch 8/10, Train Loss: 0.4880, Train Accuracy: 0.8194, Test Loss: 0.5498, Test Accuracy: 0.7436
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 29.04it/s]
# Epoch 9/10, Train Loss: 0.4909, Train Accuracy: 0.7952, Test Loss: 0.5646, Test Accuracy: 0.7308
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 29.23it/s]
# Epoch 10/10, Train Loss: 0.5011, Train Accuracy: 0.8048, Test Loss: 0.5501, Test Accuracy: 0.7628
# Model saved to ./checkpoints/nn_0_vs_3.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 27.16it/s]
# Epoch 1/10, Train Loss: 0.5032, Train Accuracy: 0.7952, Test Loss: 0.5665, Test Accuracy: 0.7628
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.17it/s]
# Epoch 2/10, Train Loss: 0.4960, Train Accuracy: 0.7887, Test Loss: 0.5368, Test Accuracy: 0.7692
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 28.35it/s]
# Epoch 3/10, Train Loss: 0.4660, Train Accuracy: 0.8210, Test Loss: 0.5028, Test Accuracy: 0.7949
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 27.92it/s]
# Epoch 4/10, Train Loss: 0.4471, Train Accuracy: 0.8290, Test Loss: 0.5144, Test Accuracy: 0.7692
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 27.09it/s]
# Epoch 5/10, Train Loss: 0.4514, Train Accuracy: 0.8242, Test Loss: 0.5376, Test Accuracy: 0.7436
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 27.67it/s]
# Epoch 6/10, Train Loss: 0.4403, Train Accuracy: 0.8274, Test Loss: 0.4911, Test Accuracy: 0.7821
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 28.27it/s]
# Epoch 7/10, Train Loss: 0.4466, Train Accuracy: 0.8210, Test Loss: 0.5033, Test Accuracy: 0.8141
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 27.81it/s]
# Epoch 8/10, Train Loss: 0.4375, Train Accuracy: 0.8355, Test Loss: 0.5129, Test Accuracy: 0.8141
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 28.14it/s]
# Epoch 9/10, Train Loss: 0.4518, Train Accuracy: 0.8145, Test Loss: 0.5057, Test Accuracy: 0.7885
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 26.99it/s]
# Epoch 10/10, Train Loss: 0.4485, Train Accuracy: 0.8210, Test Loss: 0.5677, Test Accuracy: 0.7500
# Model saved to ./checkpoints/mlp_0_vs_3.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 18.45it/s]
# Epoch 1/10, Train Loss: 0.4185, Train Accuracy: 0.8113, Test Loss: 0.3997, Test Accuracy: 0.8333
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 17.99it/s]
# Epoch 2/10, Train Loss: 0.2852, Train Accuracy: 0.8726, Test Loss: 0.2981, Test Accuracy: 0.8654
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 18.77it/s]
# Epoch 3/10, Train Loss: 0.2579, Train Accuracy: 0.8935, Test Loss: 0.3400, Test Accuracy: 0.8526
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 17.99it/s]
# Epoch 4/10, Train Loss: 0.2452, Train Accuracy: 0.8919, Test Loss: 0.3142, Test Accuracy: 0.8782
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 18.18it/s]
# Epoch 5/10, Train Loss: 0.2450, Train Accuracy: 0.8968, Test Loss: 0.3609, Test Accuracy: 0.8462
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 19.04it/s]
# Epoch 6/10, Train Loss: 0.2051, Train Accuracy: 0.9210, Test Loss: 0.2688, Test Accuracy: 0.8718
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 17.97it/s]
# Epoch 7/10, Train Loss: 0.2198, Train Accuracy: 0.9145, Test Loss: 0.3477, Test Accuracy: 0.8782
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 18.27it/s]
# Epoch 8/10, Train Loss: 0.2052, Train Accuracy: 0.9113, Test Loss: 0.3640, Test Accuracy: 0.8526
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 18.55it/s]
# Epoch 9/10, Train Loss: 0.1905, Train Accuracy: 0.9177, Test Loss: 0.2622, Test Accuracy: 0.8718
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 18.94it/s]
# Epoch 10/10, Train Loss: 0.2078, Train Accuracy: 0.9210, Test Loss: 0.2313, Test Accuracy: 0.8846
# Model saved to ./checkpoints/cnn_0_vs_3.pth
# Training model for pair: 0 vs 4
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 29.08it/s]
# Epoch 1/10, Train Loss: 0.6092, Train Accuracy: 0.6758, Test Loss: 0.5533, Test Accuracy: 0.6859
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.44it/s]
# Epoch 2/10, Train Loss: 0.5990, Train Accuracy: 0.7065, Test Loss: 0.5708, Test Accuracy: 0.7051
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 27.20it/s]
# Epoch 3/10, Train Loss: 0.5716, Train Accuracy: 0.7016, Test Loss: 0.5178, Test Accuracy: 0.7500
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 28.94it/s]
# Epoch 4/10, Train Loss: 0.5671, Train Accuracy: 0.7081, Test Loss: 0.5645, Test Accuracy: 0.7115
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 27.39it/s]
# Epoch 5/10, Train Loss: 0.5752, Train Accuracy: 0.6935, Test Loss: 0.5263, Test Accuracy: 0.7308
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 28.24it/s]
# Epoch 6/10, Train Loss: 0.5684, Train Accuracy: 0.7097, Test Loss: 0.5219, Test Accuracy: 0.7564
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 28.25it/s]
# Epoch 7/10, Train Loss: 0.5486, Train Accuracy: 0.7161, Test Loss: 0.5555, Test Accuracy: 0.7115
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 29.31it/s]
# Epoch 8/10, Train Loss: 0.5446, Train Accuracy: 0.7323, Test Loss: 0.5235, Test Accuracy: 0.7500
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 29.29it/s]
# Epoch 9/10, Train Loss: 0.5225, Train Accuracy: 0.7516, Test Loss: 0.5261, Test Accuracy: 0.7372
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 29.13it/s]
# Epoch 10/10, Train Loss: 0.5154, Train Accuracy: 0.7548, Test Loss: 0.4871, Test Accuracy: 0.7500
# Model saved to ./checkpoints/nn_0_vs_4.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 27.78it/s]
# Epoch 1/10, Train Loss: 0.6192, Train Accuracy: 0.6952, Test Loss: 0.5160, Test Accuracy: 0.7372
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.31it/s]
# Epoch 2/10, Train Loss: 0.5700, Train Accuracy: 0.7129, Test Loss: 0.5072, Test Accuracy: 0.7372
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 27.38it/s]
# Epoch 3/10, Train Loss: 0.5370, Train Accuracy: 0.7387, Test Loss: 0.5022, Test Accuracy: 0.7436
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 26.94it/s]
# Epoch 4/10, Train Loss: 0.5241, Train Accuracy: 0.7613, Test Loss: 0.5116, Test Accuracy: 0.7436
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 27.94it/s]
# Epoch 5/10, Train Loss: 0.5119, Train Accuracy: 0.7548, Test Loss: 0.4897, Test Accuracy: 0.7756
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 27.35it/s]
# Epoch 6/10, Train Loss: 0.4898, Train Accuracy: 0.7710, Test Loss: 0.5156, Test Accuracy: 0.7436
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 27.33it/s]
# Epoch 7/10, Train Loss: 0.4801, Train Accuracy: 0.7887, Test Loss: 0.4987, Test Accuracy: 0.7372
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 28.29it/s]
# Epoch 8/10, Train Loss: 0.4683, Train Accuracy: 0.7806, Test Loss: 0.4523, Test Accuracy: 0.8141
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 26.51it/s]
# Epoch 9/10, Train Loss: 0.4626, Train Accuracy: 0.7952, Test Loss: 0.4625, Test Accuracy: 0.7949
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 26.93it/s]
# Epoch 10/10, Train Loss: 0.4605, Train Accuracy: 0.7952, Test Loss: 0.4473, Test Accuracy: 0.8077
# Model saved to ./checkpoints/mlp_0_vs_4.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 19.93it/s]
# Epoch 1/10, Train Loss: 0.3458, Train Accuracy: 0.8661, Test Loss: 0.2470, Test Accuracy: 0.8910
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 19.10it/s]
# Epoch 2/10, Train Loss: 0.2300, Train Accuracy: 0.9000, Test Loss: 0.1617, Test Accuracy: 0.9359
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 18.46it/s]
# Epoch 3/10, Train Loss: 0.2008, Train Accuracy: 0.9194, Test Loss: 0.1990, Test Accuracy: 0.9103
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 19.07it/s]
# Epoch 4/10, Train Loss: 0.1959, Train Accuracy: 0.9194, Test Loss: 0.1590, Test Accuracy: 0.9359
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 19.06it/s]
# Epoch 5/10, Train Loss: 0.1704, Train Accuracy: 0.9274, Test Loss: 0.1631, Test Accuracy: 0.9231
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 17.99it/s]
# Epoch 6/10, Train Loss: 0.1509, Train Accuracy: 0.9403, Test Loss: 0.1534, Test Accuracy: 0.9167
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 18.43it/s]
# Epoch 7/10, Train Loss: 0.1448, Train Accuracy: 0.9387, Test Loss: 0.2002, Test Accuracy: 0.8974
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 18.88it/s]
# Epoch 8/10, Train Loss: 0.1283, Train Accuracy: 0.9468, Test Loss: 0.1443, Test Accuracy: 0.9231
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 19.25it/s]
# Epoch 9/10, Train Loss: 0.1192, Train Accuracy: 0.9500, Test Loss: 0.1545, Test Accuracy: 0.9295
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 20.44it/s]
# Epoch 10/10, Train Loss: 0.1127, Train Accuracy: 0.9516, Test Loss: 0.1514, Test Accuracy: 0.9295
# Model saved to ./checkpoints/cnn_0_vs_4.pth
# Training model for pair: 0 vs 5
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 27.40it/s]
# Epoch 1/10, Train Loss: 0.5532, Train Accuracy: 0.7258, Test Loss: 0.4767, Test Accuracy: 0.8141
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.98it/s]
# Epoch 2/10, Train Loss: 0.5370, Train Accuracy: 0.7323, Test Loss: 0.4399, Test Accuracy: 0.8141
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 28.78it/s]
# Epoch 3/10, Train Loss: 0.5329, Train Accuracy: 0.7516, Test Loss: 0.4337, Test Accuracy: 0.8205
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 28.81it/s]
# Epoch 4/10, Train Loss: 0.5270, Train Accuracy: 0.7290, Test Loss: 0.4403, Test Accuracy: 0.8013
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 29.31it/s]
# Epoch 5/10, Train Loss: 0.5109, Train Accuracy: 0.7484, Test Loss: 0.4161, Test Accuracy: 0.8590
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 28.99it/s]
# Epoch 6/10, Train Loss: 0.5087, Train Accuracy: 0.7726, Test Loss: 0.4383, Test Accuracy: 0.8526
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 28.87it/s]
# Epoch 7/10, Train Loss: 0.5066, Train Accuracy: 0.7742, Test Loss: 0.4193, Test Accuracy: 0.8590
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 28.99it/s]
# Epoch 8/10, Train Loss: 0.4903, Train Accuracy: 0.7790, Test Loss: 0.4194, Test Accuracy: 0.8333
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 29.04it/s]
# Epoch 9/10, Train Loss: 0.4847, Train Accuracy: 0.7887, Test Loss: 0.4171, Test Accuracy: 0.8526
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 29.12it/s]
# Epoch 10/10, Train Loss: 0.4840, Train Accuracy: 0.7855, Test Loss: 0.3860, Test Accuracy: 0.8846
# Model saved to ./checkpoints/nn_0_vs_5.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 25.15it/s]
# Epoch 1/10, Train Loss: 0.4829, Train Accuracy: 0.7758, Test Loss: 0.3923, Test Accuracy: 0.8526
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 25.61it/s]
# Epoch 2/10, Train Loss: 0.4668, Train Accuracy: 0.7790, Test Loss: 0.3767, Test Accuracy: 0.8462
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 25.97it/s]
# Epoch 3/10, Train Loss: 0.4855, Train Accuracy: 0.7710, Test Loss: 0.4305, Test Accuracy: 0.8141
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 25.65it/s]
# Epoch 4/10, Train Loss: 0.4336, Train Accuracy: 0.8032, Test Loss: 0.3507, Test Accuracy: 0.8910
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 26.52it/s]
# Epoch 5/10, Train Loss: 0.4307, Train Accuracy: 0.8177, Test Loss: 0.3522, Test Accuracy: 0.8846
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 24.22it/s]
# Epoch 6/10, Train Loss: 0.4099, Train Accuracy: 0.8194, Test Loss: 0.3636, Test Accuracy: 0.8590
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 25.48it/s]
# Epoch 7/10, Train Loss: 0.4014, Train Accuracy: 0.8371, Test Loss: 0.3325, Test Accuracy: 0.8846
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 26.01it/s]
# Epoch 8/10, Train Loss: 0.3989, Train Accuracy: 0.8387, Test Loss: 0.3548, Test Accuracy: 0.8654
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 25.76it/s]
# Epoch 9/10, Train Loss: 0.4011, Train Accuracy: 0.8403, Test Loss: 0.3528, Test Accuracy: 0.8526
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 25.81it/s]
# Epoch 10/10, Train Loss: 0.3887, Train Accuracy: 0.8532, Test Loss: 0.3230, Test Accuracy: 0.8782
# Model saved to ./checkpoints/mlp_0_vs_5.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 17.37it/s]
# Epoch 1/10, Train Loss: 0.1336, Train Accuracy: 0.9371, Test Loss: 0.1344, Test Accuracy: 0.9295
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 18.37it/s]
# Epoch 2/10, Train Loss: 0.1196, Train Accuracy: 0.9452, Test Loss: 0.0973, Test Accuracy: 0.9551
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 18.43it/s]
# Epoch 3/10, Train Loss: 0.1001, Train Accuracy: 0.9548, Test Loss: 0.1025, Test Accuracy: 0.9551
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 17.39it/s]
# Epoch 4/10, Train Loss: 0.1020, Train Accuracy: 0.9468, Test Loss: 0.1058, Test Accuracy: 0.9551
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 18.74it/s]
# Epoch 5/10, Train Loss: 0.0908, Train Accuracy: 0.9581, Test Loss: 0.1070, Test Accuracy: 0.9551
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 16.86it/s]
# Epoch 6/10, Train Loss: 0.0958, Train Accuracy: 0.9500, Test Loss: 0.0950, Test Accuracy: 0.9551
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 17.04it/s]
# Epoch 7/10, Train Loss: 0.1029, Train Accuracy: 0.9484, Test Loss: 0.1065, Test Accuracy: 0.9359
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 17.67it/s]
# Epoch 8/10, Train Loss: 0.0813, Train Accuracy: 0.9548, Test Loss: 0.1119, Test Accuracy: 0.9423
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 19.02it/s]
# Epoch 9/10, Train Loss: 0.0806, Train Accuracy: 0.9548, Test Loss: 0.0746, Test Accuracy: 0.9679
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 16.46it/s]
# Epoch 10/10, Train Loss: 0.0941, Train Accuracy: 0.9484, Test Loss: 0.1160, Test Accuracy: 0.9359
# Model saved to ./checkpoints/cnn_0_vs_5.pth
# Training model for pair: 0 vs 6
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 28.10it/s]
# Epoch 1/10, Train Loss: 0.7127, Train Accuracy: 0.5790, Test Loss: 0.7100, Test Accuracy: 0.5897
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 28.74it/s]
# Epoch 2/10, Train Loss: 0.6907, Train Accuracy: 0.5984, Test Loss: 0.7258, Test Accuracy: 0.5513
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 27.20it/s]
# Epoch 3/10, Train Loss: 0.6971, Train Accuracy: 0.6032, Test Loss: 0.6362, Test Accuracy: 0.6603
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 29.70it/s]
# Epoch 4/10, Train Loss: 0.6852, Train Accuracy: 0.6113, Test Loss: 0.6384, Test Accuracy: 0.6346
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 29.95it/s]
# Epoch 5/10, Train Loss: 0.6670, Train Accuracy: 0.6387, Test Loss: 0.6755, Test Accuracy: 0.5897
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 28.66it/s]
# Epoch 6/10, Train Loss: 0.6450, Train Accuracy: 0.6548, Test Loss: 0.7066, Test Accuracy: 0.5897
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 28.15it/s]
# Epoch 7/10, Train Loss: 0.6557, Train Accuracy: 0.6452, Test Loss: 0.6885, Test Accuracy: 0.6026
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 29.54it/s]
# Epoch 8/10, Train Loss: 0.6494, Train Accuracy: 0.6323, Test Loss: 0.6210, Test Accuracy: 0.6731
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 29.32it/s]
# Epoch 9/10, Train Loss: 0.6438, Train Accuracy: 0.6500, Test Loss: 0.6458, Test Accuracy: 0.6538
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 29.47it/s]
# Epoch 10/10, Train Loss: 0.6637, Train Accuracy: 0.6226, Test Loss: 0.6405, Test Accuracy: 0.6346
# Model saved to ./checkpoints/nn_0_vs_6.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 28.00it/s]
# Epoch 1/10, Train Loss: 0.7104, Train Accuracy: 0.6065, Test Loss: 0.6234, Test Accuracy: 0.6859
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 25.70it/s]
# Epoch 2/10, Train Loss: 0.6507, Train Accuracy: 0.6290, Test Loss: 0.6055, Test Accuracy: 0.6859
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 26.22it/s]
# Epoch 3/10, Train Loss: 0.6458, Train Accuracy: 0.6290, Test Loss: 0.6676, Test Accuracy: 0.5705
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 26.83it/s]
# Epoch 4/10, Train Loss: 0.6558, Train Accuracy: 0.5984, Test Loss: 0.6381, Test Accuracy: 0.5449
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 27.30it/s]
# Epoch 5/10, Train Loss: 0.6406, Train Accuracy: 0.6145, Test Loss: 0.6022, Test Accuracy: 0.7051
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 27.17it/s]
# Epoch 6/10, Train Loss: 0.6217, Train Accuracy: 0.6532, Test Loss: 0.5935, Test Accuracy: 0.6731
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 27.96it/s]
# Epoch 7/10, Train Loss: 0.6218, Train Accuracy: 0.6629, Test Loss: 0.5926, Test Accuracy: 0.7372
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 26.30it/s]
# Epoch 8/10, Train Loss: 0.6226, Train Accuracy: 0.6790, Test Loss: 0.5848, Test Accuracy: 0.7115
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 26.33it/s]
# Epoch 9/10, Train Loss: 0.6010, Train Accuracy: 0.6790, Test Loss: 0.5635, Test Accuracy: 0.7115
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 26.80it/s]
# Epoch 10/10, Train Loss: 0.5929, Train Accuracy: 0.6887, Test Loss: 0.6097, Test Accuracy: 0.6346
# Model saved to ./checkpoints/mlp_0_vs_6.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 18.21it/s]
# Epoch 1/10, Train Loss: 0.3452, Train Accuracy: 0.8355, Test Loss: 0.2602, Test Accuracy: 0.8654
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 18.67it/s]
# Epoch 2/10, Train Loss: 0.2272, Train Accuracy: 0.8935, Test Loss: 0.2125, Test Accuracy: 0.8910
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 19.28it/s]
# Epoch 3/10, Train Loss: 0.2072, Train Accuracy: 0.9065, Test Loss: 0.2574, Test Accuracy: 0.8718
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 18.94it/s]
# Epoch 4/10, Train Loss: 0.1843, Train Accuracy: 0.9065, Test Loss: 0.2222, Test Accuracy: 0.8910
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 18.18it/s]
# Epoch 5/10, Train Loss: 0.1804, Train Accuracy: 0.9016, Test Loss: 0.2244, Test Accuracy: 0.8910
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 16.73it/s]
# Epoch 6/10, Train Loss: 0.1889, Train Accuracy: 0.9065, Test Loss: 0.2020, Test Accuracy: 0.9103
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 16.69it/s]
# Epoch 7/10, Train Loss: 0.1481, Train Accuracy: 0.9290, Test Loss: 0.2185, Test Accuracy: 0.8910
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 18.55it/s]
# Epoch 8/10, Train Loss: 0.1471, Train Accuracy: 0.9355, Test Loss: 0.1748, Test Accuracy: 0.9295
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 18.49it/s]
# Epoch 9/10, Train Loss: 0.1446, Train Accuracy: 0.9242, Test Loss: 0.1905, Test Accuracy: 0.8782
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 17.64it/s]
# Epoch 10/10, Train Loss: 0.1296, Train Accuracy: 0.9258, Test Loss: 0.2142, Test Accuracy: 0.9167
# Model saved to ./checkpoints/cnn_0_vs_6.pth
# Training model for pair: 0 vs 7
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 29.64it/s]
# Epoch 1/10, Train Loss: 0.6214, Train Accuracy: 0.6726, Test Loss: 0.6504, Test Accuracy: 0.6282
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 29.87it/s]
# Epoch 2/10, Train Loss: 0.6262, Train Accuracy: 0.6645, Test Loss: 0.6252, Test Accuracy: 0.6538
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 29.97it/s]
# Epoch 3/10, Train Loss: 0.5981, Train Accuracy: 0.6871, Test Loss: 0.6072, Test Accuracy: 0.6859
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 29.99it/s]
# Epoch 4/10, Train Loss: 0.5791, Train Accuracy: 0.7065, Test Loss: 0.6159, Test Accuracy: 0.6923
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 29.76it/s]
# Epoch 5/10, Train Loss: 0.5921, Train Accuracy: 0.6903, Test Loss: 0.5747, Test Accuracy: 0.7179
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 29.91it/s]
# Epoch 6/10, Train Loss: 0.5691, Train Accuracy: 0.7210, Test Loss: 0.5489, Test Accuracy: 0.7244
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 30.11it/s]
# Epoch 7/10, Train Loss: 0.5616, Train Accuracy: 0.7403, Test Loss: 0.5601, Test Accuracy: 0.7372
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 29.55it/s]
# Epoch 8/10, Train Loss: 0.5524, Train Accuracy: 0.7210, Test Loss: 0.5600, Test Accuracy: 0.7244
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 29.81it/s]
# Epoch 9/10, Train Loss: 0.5544, Train Accuracy: 0.7339, Test Loss: 0.6121, Test Accuracy: 0.7372
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 28.95it/s]
# Epoch 10/10, Train Loss: 0.5587, Train Accuracy: 0.7242, Test Loss: 0.5789, Test Accuracy: 0.7308
# Model saved to ./checkpoints/nn_0_vs_7.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 25.83it/s]
# Epoch 1/10, Train Loss: 0.5652, Train Accuracy: 0.7081, Test Loss: 0.5567, Test Accuracy: 0.7179
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 25.97it/s]
# Epoch 2/10, Train Loss: 0.5384, Train Accuracy: 0.7403, Test Loss: 0.5856, Test Accuracy: 0.7115
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 26.62it/s]
# Epoch 3/10, Train Loss: 0.5414, Train Accuracy: 0.7258, Test Loss: 0.5447, Test Accuracy: 0.7564
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 25.23it/s]
# Epoch 4/10, Train Loss: 0.5331, Train Accuracy: 0.7339, Test Loss: 0.5444, Test Accuracy: 0.7179
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 24.39it/s]
# Epoch 5/10, Train Loss: 0.5186, Train Accuracy: 0.7629, Test Loss: 0.5482, Test Accuracy: 0.7564
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 26.02it/s]
# Epoch 6/10, Train Loss: 0.5136, Train Accuracy: 0.7532, Test Loss: 0.5433, Test Accuracy: 0.7436
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 25.40it/s]
# Epoch 7/10, Train Loss: 0.4987, Train Accuracy: 0.7710, Test Loss: 0.5220, Test Accuracy: 0.7308
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 26.07it/s]
# Epoch 8/10, Train Loss: 0.4810, Train Accuracy: 0.7839, Test Loss: 0.5182, Test Accuracy: 0.7436
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 27.81it/s]
# Epoch 9/10, Train Loss: 0.4779, Train Accuracy: 0.7823, Test Loss: 0.5015, Test Accuracy: 0.8077
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 25.69it/s]
# Epoch 10/10, Train Loss: 0.4694, Train Accuracy: 0.8032, Test Loss: 0.4882, Test Accuracy: 0.7436
# Model saved to ./checkpoints/mlp_0_vs_7.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 16.35it/s]
# Epoch 1/10, Train Loss: 0.1988, Train Accuracy: 0.8984, Test Loss: 0.2209, Test Accuracy: 0.9359
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 17.01it/s]
# Epoch 2/10, Train Loss: 0.1649, Train Accuracy: 0.9306, Test Loss: 0.2569, Test Accuracy: 0.8782
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 17.73it/s]
# Epoch 3/10, Train Loss: 0.1465, Train Accuracy: 0.9355, Test Loss: 0.2075, Test Accuracy: 0.8782
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 17.00it/s]
# Epoch 4/10, Train Loss: 0.1293, Train Accuracy: 0.9355, Test Loss: 0.1686, Test Accuracy: 0.9103
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 17.57it/s]
# Epoch 5/10, Train Loss: 0.1076, Train Accuracy: 0.9403, Test Loss: 0.1615, Test Accuracy: 0.9167
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 12.97it/s]
# Epoch 6/10, Train Loss: 0.1023, Train Accuracy: 0.9452, Test Loss: 0.1576, Test Accuracy: 0.8910
# Epoch 7/10: 100%|██████████| 20/20 [00:02<00:00,  8.61it/s]
# Epoch 7/10, Train Loss: 0.1135, Train Accuracy: 0.9452, Test Loss: 0.1767, Test Accuracy: 0.8910
# Epoch 8/10: 100%|██████████| 20/20 [00:02<00:00,  8.96it/s]
# Epoch 8/10, Train Loss: 0.1076, Train Accuracy: 0.9565, Test Loss: 0.1676, Test Accuracy: 0.8910
# Epoch 9/10: 100%|██████████| 20/20 [00:02<00:00,  8.91it/s]
# Epoch 9/10, Train Loss: 0.0882, Train Accuracy: 0.9581, Test Loss: 0.1364, Test Accuracy: 0.8974
# Epoch 10/10: 100%|██████████| 20/20 [00:02<00:00,  9.49it/s]
# Epoch 10/10, Train Loss: 0.0803, Train Accuracy: 0.9548, Test Loss: 0.1902, Test Accuracy: 0.8910
# Model saved to ./checkpoints/cnn_0_vs_7.pth
# Training model for pair: 0 vs 8
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 15.23it/s]
# Epoch 1/10, Train Loss: 0.6524, Train Accuracy: 0.6194, Test Loss: 0.6758, Test Accuracy: 0.6090
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 15.11it/s]
# Epoch 2/10, Train Loss: 0.6587, Train Accuracy: 0.6274, Test Loss: 0.6723, Test Accuracy: 0.6026
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 15.09it/s]
# Epoch 3/10, Train Loss: 0.6301, Train Accuracy: 0.6694, Test Loss: 0.6564, Test Accuracy: 0.6282
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 14.95it/s]
# Epoch 4/10, Train Loss: 0.6237, Train Accuracy: 0.6742, Test Loss: 0.6776, Test Accuracy: 0.6026
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 15.44it/s]
# Epoch 5/10, Train Loss: 0.6342, Train Accuracy: 0.6323, Test Loss: 0.6715, Test Accuracy: 0.6795
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 15.37it/s]
# Epoch 6/10, Train Loss: 0.6123, Train Accuracy: 0.7097, Test Loss: 0.6649, Test Accuracy: 0.6410
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 15.24it/s]
# Epoch 7/10, Train Loss: 0.6198, Train Accuracy: 0.6758, Test Loss: 0.6530, Test Accuracy: 0.6795
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 15.30it/s]
# Epoch 8/10, Train Loss: 0.5973, Train Accuracy: 0.7129, Test Loss: 0.6811, Test Accuracy: 0.6795
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 14.94it/s]
# Epoch 9/10, Train Loss: 0.6113, Train Accuracy: 0.6952, Test Loss: 0.6691, Test Accuracy: 0.5833
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 15.84it/s]
# Epoch 10/10, Train Loss: 0.6000, Train Accuracy: 0.7081, Test Loss: 0.6460, Test Accuracy: 0.6218
# Model saved to ./checkpoints/nn_0_vs_8.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 12.04it/s]
# Epoch 1/10, Train Loss: 0.5863, Train Accuracy: 0.7065, Test Loss: 0.6235, Test Accuracy: 0.6795
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 11.91it/s]
# Epoch 2/10, Train Loss: 0.5588, Train Accuracy: 0.7387, Test Loss: 0.5962, Test Accuracy: 0.6987
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 12.06it/s]
# Epoch 3/10, Train Loss: 0.5619, Train Accuracy: 0.7419, Test Loss: 0.5823, Test Accuracy: 0.7051
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 13.24it/s]
# Epoch 4/10, Train Loss: 0.5372, Train Accuracy: 0.7758, Test Loss: 0.5802, Test Accuracy: 0.6923
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 12.61it/s]
# Epoch 5/10, Train Loss: 0.5196, Train Accuracy: 0.7903, Test Loss: 0.6133, Test Accuracy: 0.6603
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 13.17it/s]
# Epoch 6/10, Train Loss: 0.5338, Train Accuracy: 0.7694, Test Loss: 0.5630, Test Accuracy: 0.7244
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 12.59it/s]
# Epoch 7/10, Train Loss: 0.5116, Train Accuracy: 0.7855, Test Loss: 0.5863, Test Accuracy: 0.7500
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 13.73it/s]
# Epoch 8/10, Train Loss: 0.5209, Train Accuracy: 0.7629, Test Loss: 0.5483, Test Accuracy: 0.7115
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 12.42it/s]
# Epoch 9/10, Train Loss: 0.5011, Train Accuracy: 0.7919, Test Loss: 0.5598, Test Accuracy: 0.7372
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 14.11it/s]
# Epoch 10/10, Train Loss: 0.4949, Train Accuracy: 0.8032, Test Loss: 0.5665, Test Accuracy: 0.7436
# Model saved to ./checkpoints/mlp_0_vs_8.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:02<00:00,  8.53it/s]
# Epoch 1/10, Train Loss: 0.1438, Train Accuracy: 0.9226, Test Loss: 0.1956, Test Accuracy: 0.9038
# Epoch 2/10: 100%|██████████| 20/20 [00:02<00:00,  8.36it/s]
# Epoch 2/10, Train Loss: 0.1441, Train Accuracy: 0.9371, Test Loss: 0.2329, Test Accuracy: 0.8974
# Epoch 3/10: 100%|██████████| 20/20 [00:02<00:00,  8.61it/s]
# Epoch 3/10, Train Loss: 0.1272, Train Accuracy: 0.9419, Test Loss: 0.2178, Test Accuracy: 0.9038
# Epoch 4/10: 100%|██████████| 20/20 [00:02<00:00,  8.64it/s]
# Epoch 4/10, Train Loss: 0.1011, Train Accuracy: 0.9500, Test Loss: 0.1940, Test Accuracy: 0.9103
# Epoch 5/10: 100%|██████████| 20/20 [00:02<00:00,  8.51it/s]
# Epoch 5/10, Train Loss: 0.1231, Train Accuracy: 0.9387, Test Loss: 0.2496, Test Accuracy: 0.9295
# Epoch 6/10: 100%|██████████| 20/20 [00:02<00:00,  8.54it/s]
# Epoch 6/10, Train Loss: 0.1059, Train Accuracy: 0.9484, Test Loss: 0.2057, Test Accuracy: 0.9231
# Epoch 7/10: 100%|██████████| 20/20 [00:02<00:00,  8.91it/s]
# Epoch 7/10, Train Loss: 0.0924, Train Accuracy: 0.9581, Test Loss: 0.1482, Test Accuracy: 0.9231
# Epoch 8/10: 100%|██████████| 20/20 [00:02<00:00,  8.79it/s]
# Epoch 8/10, Train Loss: 0.0913, Train Accuracy: 0.9452, Test Loss: 0.2563, Test Accuracy: 0.8974
# Epoch 9/10: 100%|██████████| 20/20 [00:02<00:00,  8.92it/s]
# Epoch 9/10, Train Loss: 0.1103, Train Accuracy: 0.9403, Test Loss: 0.2484, Test Accuracy: 0.9231
# Epoch 10/10: 100%|██████████| 20/20 [00:02<00:00,  9.17it/s]
# Epoch 10/10, Train Loss: 0.0868, Train Accuracy: 0.9516, Test Loss: 0.1487, Test Accuracy: 0.9295
# Model saved to ./checkpoints/cnn_0_vs_8.pth
# Training model for pair: 0 vs 9
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 14.80it/s]
# Epoch 1/10, Train Loss: 0.5885, Train Accuracy: 0.7048, Test Loss: 0.5417, Test Accuracy: 0.7628
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 16.49it/s]
# Epoch 2/10, Train Loss: 0.5925, Train Accuracy: 0.6968, Test Loss: 0.5123, Test Accuracy: 0.7821
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 16.03it/s]
# Epoch 3/10, Train Loss: 0.5752, Train Accuracy: 0.7419, Test Loss: 0.5109, Test Accuracy: 0.7628
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 28.35it/s]
# Epoch 4/10, Train Loss: 0.5630, Train Accuracy: 0.7194, Test Loss: 0.4994, Test Accuracy: 0.7885
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 29.55it/s]
# Epoch 5/10, Train Loss: 0.5471, Train Accuracy: 0.7452, Test Loss: 0.4876, Test Accuracy: 0.7628
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 29.96it/s]
# Epoch 6/10, Train Loss: 0.5324, Train Accuracy: 0.7484, Test Loss: 0.4748, Test Accuracy: 0.8269
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 29.64it/s]
# Epoch 7/10, Train Loss: 0.5470, Train Accuracy: 0.7371, Test Loss: 0.4862, Test Accuracy: 0.8269
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 29.56it/s]
# Epoch 8/10, Train Loss: 0.5531, Train Accuracy: 0.7306, Test Loss: 0.5117, Test Accuracy: 0.7821
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 29.23it/s]
# Epoch 9/10, Train Loss: 0.5282, Train Accuracy: 0.7726, Test Loss: 0.4607, Test Accuracy: 0.8462
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 30.05it/s]
# Epoch 10/10, Train Loss: 0.5167, Train Accuracy: 0.7581, Test Loss: 0.4577, Test Accuracy: 0.8397
# Model saved to ./checkpoints/nn_0_vs_9.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 26.92it/s]
# Epoch 1/10, Train Loss: 0.5209, Train Accuracy: 0.7694, Test Loss: 0.4540, Test Accuracy: 0.8397
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 27.22it/s]
# Epoch 2/10, Train Loss: 0.4930, Train Accuracy: 0.7887, Test Loss: 0.4700, Test Accuracy: 0.7885
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 25.92it/s]
# Epoch 3/10, Train Loss: 0.4937, Train Accuracy: 0.7887, Test Loss: 0.5304, Test Accuracy: 0.7308
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 25.81it/s]
# Epoch 4/10, Train Loss: 0.4804, Train Accuracy: 0.7919, Test Loss: 0.4285, Test Accuracy: 0.8333
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 25.46it/s]
# Epoch 5/10, Train Loss: 0.4604, Train Accuracy: 0.8000, Test Loss: 0.4283, Test Accuracy: 0.8269
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 26.35it/s]
# Epoch 6/10, Train Loss: 0.4618, Train Accuracy: 0.7952, Test Loss: 0.4473, Test Accuracy: 0.8077
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 27.28it/s]
# Epoch 7/10, Train Loss: 0.4656, Train Accuracy: 0.7935, Test Loss: 0.4224, Test Accuracy: 0.8013
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 28.69it/s]
# Epoch 8/10, Train Loss: 0.4621, Train Accuracy: 0.7968, Test Loss: 0.4380, Test Accuracy: 0.8013
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 27.54it/s]
# Epoch 9/10, Train Loss: 0.4334, Train Accuracy: 0.8145, Test Loss: 0.4527, Test Accuracy: 0.7885
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 27.21it/s]
# Epoch 10/10, Train Loss: 0.4210, Train Accuracy: 0.8274, Test Loss: 0.3928, Test Accuracy: 0.8526
# Model saved to ./checkpoints/mlp_0_vs_9.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 18.35it/s]
# Epoch 1/10, Train Loss: 0.1333, Train Accuracy: 0.9210, Test Loss: 0.1480, Test Accuracy: 0.9359
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 16.72it/s]
# Epoch 2/10, Train Loss: 0.1032, Train Accuracy: 0.9452, Test Loss: 0.1017, Test Accuracy: 0.9615
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 16.33it/s]
# Epoch 3/10, Train Loss: 0.1019, Train Accuracy: 0.9484, Test Loss: 0.1078, Test Accuracy: 0.9295
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 16.99it/s]
# Epoch 4/10, Train Loss: 0.0960, Train Accuracy: 0.9484, Test Loss: 0.1178, Test Accuracy: 0.9423
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 17.97it/s]
# Epoch 5/10, Train Loss: 0.0994, Train Accuracy: 0.9484, Test Loss: 0.1207, Test Accuracy: 0.9295
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 17.59it/s]
# Epoch 6/10, Train Loss: 0.0790, Train Accuracy: 0.9484, Test Loss: 0.1357, Test Accuracy: 0.9359
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 17.79it/s]
# Epoch 7/10, Train Loss: 0.0946, Train Accuracy: 0.9484, Test Loss: 0.1948, Test Accuracy: 0.9295
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 16.95it/s]
# Epoch 8/10, Train Loss: 0.0908, Train Accuracy: 0.9532, Test Loss: 0.1413, Test Accuracy: 0.9359
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 17.91it/s]
# Epoch 9/10, Train Loss: 0.0783, Train Accuracy: 0.9661, Test Loss: 0.0984, Test Accuracy: 0.9551
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 18.11it/s]
# Epoch 10/10, Train Loss: 0.0802, Train Accuracy: 0.9581, Test Loss: 0.1438, Test Accuracy: 0.9359
# Model saved to ./checkpoints/cnn_0_vs_9.pth
# Training model for pair: 1 vs 2
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 27.55it/s]
# Epoch 1/10, Train Loss: 0.7797, Train Accuracy: 0.5209, Test Loss: 0.7879, Test Accuracy: 0.5128
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 26.91it/s]
# Epoch 2/10, Train Loss: 0.7591, Train Accuracy: 0.5338, Test Loss: 0.7398, Test Accuracy: 0.5128
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 28.02it/s]
# Epoch 3/10, Train Loss: 0.7432, Train Accuracy: 0.5563, Test Loss: 0.8917, Test Accuracy: 0.5256
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 29.14it/s]
# Epoch 4/10, Train Loss: 0.7535, Train Accuracy: 0.5547, Test Loss: 0.7549, Test Accuracy: 0.5449
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 27.97it/s]
# Epoch 5/10, Train Loss: 0.7167, Train Accuracy: 0.5804, Test Loss: 0.6988, Test Accuracy: 0.5897
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 28.04it/s]
# Epoch 6/10, Train Loss: 0.6781, Train Accuracy: 0.6302, Test Loss: 0.7299, Test Accuracy: 0.5769
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 28.03it/s]
# Epoch 7/10, Train Loss: 0.6724, Train Accuracy: 0.6174, Test Loss: 0.7239, Test Accuracy: 0.5705
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 28.75it/s]
# Epoch 8/10, Train Loss: 0.6621, Train Accuracy: 0.6350, Test Loss: 0.6654, Test Accuracy: 0.6474
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 28.12it/s]
# Epoch 9/10, Train Loss: 0.6522, Train Accuracy: 0.6543, Test Loss: 0.6681, Test Accuracy: 0.6346
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 25.20it/s]
# Epoch 10/10, Train Loss: 0.6476, Train Accuracy: 0.6608, Test Loss: 0.6518, Test Accuracy: 0.6410
# Model saved to ./checkpoints/nn_1_vs_2.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 25.98it/s]
# Epoch 1/10, Train Loss: 0.7205, Train Accuracy: 0.5643, Test Loss: 0.7062, Test Accuracy: 0.5256
# Epoch 2/10: 100%|██████████| 20/20 [00:00<00:00, 25.22it/s]
# Epoch 2/10, Train Loss: 0.6659, Train Accuracy: 0.5981, Test Loss: 0.6863, Test Accuracy: 0.5321
# Epoch 3/10: 100%|██████████| 20/20 [00:00<00:00, 27.50it/s]
# Epoch 3/10, Train Loss: 0.6559, Train Accuracy: 0.6077, Test Loss: 0.6784, Test Accuracy: 0.5513
# Epoch 4/10: 100%|██████████| 20/20 [00:00<00:00, 27.60it/s]
# Epoch 4/10, Train Loss: 0.6297, Train Accuracy: 0.6961, Test Loss: 0.6816, Test Accuracy: 0.6154
# Epoch 5/10: 100%|██████████| 20/20 [00:00<00:00, 26.51it/s]
# Epoch 5/10, Train Loss: 0.6363, Train Accuracy: 0.6576, Test Loss: 0.6503, Test Accuracy: 0.6603
# Epoch 6/10: 100%|██████████| 20/20 [00:00<00:00, 26.85it/s]
# Epoch 6/10, Train Loss: 0.6132, Train Accuracy: 0.7042, Test Loss: 0.6591, Test Accuracy: 0.6410
# Epoch 7/10: 100%|██████████| 20/20 [00:00<00:00, 27.13it/s]
# Epoch 7/10, Train Loss: 0.5988, Train Accuracy: 0.6929, Test Loss: 0.6405, Test Accuracy: 0.6410
# Epoch 8/10: 100%|██████████| 20/20 [00:00<00:00, 26.24it/s]
# Epoch 8/10, Train Loss: 0.6033, Train Accuracy: 0.7010, Test Loss: 0.6345, Test Accuracy: 0.6346
# Epoch 9/10: 100%|██████████| 20/20 [00:00<00:00, 25.20it/s]
# Epoch 9/10, Train Loss: 0.5704, Train Accuracy: 0.7299, Test Loss: 0.6118, Test Accuracy: 0.7051
# Epoch 10/10: 100%|██████████| 20/20 [00:00<00:00, 27.01it/s]
# Epoch 10/10, Train Loss: 0.5781, Train Accuracy: 0.7203, Test Loss: 0.6189, Test Accuracy: 0.6538
# Model saved to ./checkpoints/mlp_1_vs_2.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:00<00:00, 21.34it/s]
# Epoch 1/10, Train Loss: 1.0211, Train Accuracy: 0.7605, Test Loss: 0.5888, Test Accuracy: 0.8013
# ...
# Epoch 4/10: 100%|██████████| 20/20 [00:02<00:00,  9.67it/s]
# Epoch 4/10, Train Loss: 0.1922, Train Accuracy: 0.9065, Test Loss: 0.1750, Test Accuracy: 0.9038
# Epoch 5/10: 100%|██████████| 20/20 [00:02<00:00,  9.98it/s]
# Epoch 5/10, Train Loss: 0.1722, Train Accuracy: 0.9274, Test Loss: 0.1734, Test Accuracy: 0.9295
# Epoch 6/10: 100%|██████████| 20/20 [00:02<00:00,  9.85it/s]
# Epoch 6/10, Train Loss: 0.1793, Train Accuracy: 0.9210, Test Loss: 0.1932, Test Accuracy: 0.9167
# Epoch 7/10: 100%|██████████| 20/20 [00:02<00:00,  9.32it/s]
# Epoch 7/10, Train Loss: 0.1726, Train Accuracy: 0.9194, Test Loss: 0.2133, Test Accuracy: 0.8846
# Epoch 8/10: 100%|██████████| 20/20 [00:02<00:00,  9.59it/s]
# Epoch 8/10, Train Loss: 0.1854, Train Accuracy: 0.9048, Test Loss: 0.1892, Test Accuracy: 0.8846
# Epoch 9/10: 100%|██████████| 20/20 [00:02<00:00,  9.60it/s]
# Epoch 9/10, Train Loss: 0.1788, Train Accuracy: 0.9194, Test Loss: 0.1321, Test Accuracy: 0.9295
# Epoch 10/10: 100%|██████████| 20/20 [00:02<00:00,  9.68it/s]
# Epoch 10/10, Train Loss: 0.1638, Train Accuracy: 0.9161, Test Loss: 0.1655, Test Accuracy: 0.9103
# Model saved to ./checkpoints/cnn_6_vs_9.pth
# Training model for pair: 7 vs 8
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 14.41it/s]
# Epoch 1/10, Train Loss: 0.9832, Train Accuracy: 0.3742, Test Loss: 1.0583, Test Accuracy: 0.3269
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 13.16it/s]
# Epoch 2/10, Train Loss: 0.9526, Train Accuracy: 0.4161, Test Loss: 0.9533, Test Accuracy: 0.3974
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 12.10it/s]
# Epoch 3/10, Train Loss: 0.9049, Train Accuracy: 0.4016, Test Loss: 0.9161, Test Accuracy: 0.3974
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 13.78it/s]
# Epoch 4/10, Train Loss: 0.8750, Train Accuracy: 0.4290, Test Loss: 0.9062, Test Accuracy: 0.3718
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 14.19it/s]
# Epoch 5/10, Train Loss: 0.8771, Train Accuracy: 0.4161, Test Loss: 0.8681, Test Accuracy: 0.4103
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 14.01it/s]
# Epoch 6/10, Train Loss: 0.8868, Train Accuracy: 0.4274, Test Loss: 0.8814, Test Accuracy: 0.4038
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 14.38it/s]
# Epoch 7/10, Train Loss: 0.8220, Train Accuracy: 0.4790, Test Loss: 0.8847, Test Accuracy: 0.4295
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 14.51it/s]
# Epoch 8/10, Train Loss: 0.7847, Train Accuracy: 0.4613, Test Loss: 0.8285, Test Accuracy: 0.4423
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 14.03it/s]
# Epoch 9/10, Train Loss: 0.7786, Train Accuracy: 0.5081, Test Loss: 0.8224, Test Accuracy: 0.4808
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 13.85it/s]
# Epoch 10/10, Train Loss: 0.7761, Train Accuracy: 0.4758, Test Loss: 0.7996, Test Accuracy: 0.4936
# Model saved to ./checkpoints/nn_7_vs_8.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 13.02it/s]
# Epoch 1/10, Train Loss: 0.8396, Train Accuracy: 0.4613, Test Loss: 0.7813, Test Accuracy: 0.4872
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 13.39it/s]
# Epoch 2/10, Train Loss: 0.6585, Train Accuracy: 0.6048, Test Loss: 0.6803, Test Accuracy: 0.5833
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 13.67it/s]
# Epoch 3/10, Train Loss: 0.6356, Train Accuracy: 0.6661, Test Loss: 0.6798, Test Accuracy: 0.5769
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 13.29it/s]
# Epoch 4/10, Train Loss: 0.6370, Train Accuracy: 0.6419, Test Loss: 0.6772, Test Accuracy: 0.5577
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 13.63it/s]
# Epoch 5/10, Train Loss: 0.6169, Train Accuracy: 0.6855, Test Loss: 0.6829, Test Accuracy: 0.5513
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 13.22it/s]
# Epoch 6/10, Train Loss: 0.5993, Train Accuracy: 0.6935, Test Loss: 0.6580, Test Accuracy: 0.5897
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 12.90it/s]
# Epoch 7/10, Train Loss: 0.5968, Train Accuracy: 0.7258, Test Loss: 0.6354, Test Accuracy: 0.6410
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 12.52it/s]
# Epoch 8/10, Train Loss: 0.5858, Train Accuracy: 0.7081, Test Loss: 0.6337, Test Accuracy: 0.6282
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 11.58it/s]
# Epoch 9/10, Train Loss: 0.5760, Train Accuracy: 0.7194, Test Loss: 0.6249, Test Accuracy: 0.6154
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 13.34it/s]
# Epoch 10/10, Train Loss: 0.5723, Train Accuracy: 0.7371, Test Loss: 0.6019, Test Accuracy: 0.6795
# Model saved to ./checkpoints/mlp_7_vs_8.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:02<00:00,  9.22it/s]
# Epoch 1/10, Train Loss: 1.1021, Train Accuracy: 0.5177, Test Loss: 0.6836, Test Accuracy: 0.5385
# Epoch 2/10: 100%|██████████| 20/20 [00:02<00:00,  9.76it/s]
# Epoch 2/10, Train Loss: 0.6830, Train Accuracy: 0.5548, Test Loss: 0.6828, Test Accuracy: 0.5449
# Epoch 3/10: 100%|██████████| 20/20 [00:02<00:00,  9.83it/s]
# Epoch 3/10, Train Loss: 0.6697, Train Accuracy: 0.6000, Test Loss: 0.6528, Test Accuracy: 0.6154
# Epoch 4/10: 100%|██████████| 20/20 [00:02<00:00,  9.97it/s]
# Epoch 4/10, Train Loss: 0.6444, Train Accuracy: 0.6274, Test Loss: 0.6497, Test Accuracy: 0.5897
# Epoch 5/10: 100%|██████████| 20/20 [00:02<00:00,  9.42it/s]
# Epoch 5/10, Train Loss: 0.6188, Train Accuracy: 0.6968, Test Loss: 0.5979, Test Accuracy: 0.7115
# Epoch 6/10: 100%|██████████| 20/20 [00:02<00:00,  9.55it/s]
# Epoch 6/10, Train Loss: 0.5744, Train Accuracy: 0.7339, Test Loss: 0.5610, Test Accuracy: 0.6731
# Epoch 7/10: 100%|██████████| 20/20 [00:02<00:00,  9.88it/s]
# Epoch 7/10, Train Loss: 0.5629, Train Accuracy: 0.7500, Test Loss: 0.5420, Test Accuracy: 0.7372
# Epoch 8/10: 100%|██████████| 20/20 [00:02<00:00,  9.62it/s]
# Epoch 8/10, Train Loss: 0.5243, Train Accuracy: 0.8016, Test Loss: 0.5301, Test Accuracy: 0.7756
# Epoch 9/10: 100%|██████████| 20/20 [00:02<00:00,  9.99it/s]
# Epoch 9/10, Train Loss: 0.4516, Train Accuracy: 0.8210, Test Loss: 0.4192, Test Accuracy: 0.7500
# Epoch 10/10: 100%|██████████| 20/20 [00:02<00:00,  9.64it/s]
# Epoch 10/10, Train Loss: 0.3921, Train Accuracy: 0.8161, Test Loss: 0.4155, Test Accuracy: 0.7756
# Model saved to ./checkpoints/cnn_7_vs_8.pth
# Training model for pair: 7 vs 9
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 14.45it/s]
# Epoch 1/10, Train Loss: 0.7385, Train Accuracy: 0.5323, Test Loss: 0.8150, Test Accuracy: 0.4872
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 13.83it/s]
# Epoch 2/10, Train Loss: 0.7377, Train Accuracy: 0.5371, Test Loss: 0.7737, Test Accuracy: 0.5192
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 14.16it/s]
# Epoch 3/10, Train Loss: 0.6995, Train Accuracy: 0.5613, Test Loss: 0.7434, Test Accuracy: 0.5321
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 13.95it/s]
# Epoch 4/10, Train Loss: 0.6803, Train Accuracy: 0.5823, Test Loss: 0.7225, Test Accuracy: 0.5769
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 14.14it/s]
# Epoch 5/10, Train Loss: 0.6796, Train Accuracy: 0.5952, Test Loss: 0.7120, Test Accuracy: 0.5769
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 13.69it/s]
# Epoch 6/10, Train Loss: 0.7097, Train Accuracy: 0.5581, Test Loss: 0.7214, Test Accuracy: 0.5705
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 14.24it/s]
# Epoch 7/10, Train Loss: 0.6885, Train Accuracy: 0.5919, Test Loss: 0.6673, Test Accuracy: 0.6154
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 13.82it/s]
# Epoch 8/10, Train Loss: 0.6610, Train Accuracy: 0.6210, Test Loss: 0.6735, Test Accuracy: 0.6346
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 13.93it/s]
# Epoch 9/10, Train Loss: 0.6365, Train Accuracy: 0.6597, Test Loss: 0.6493, Test Accuracy: 0.6154
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 13.53it/s]
# Epoch 10/10, Train Loss: 0.6257, Train Accuracy: 0.6516, Test Loss: 0.6383, Test Accuracy: 0.6346
# Model saved to ./checkpoints/nn_7_vs_9.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 13.35it/s]
# Epoch 1/10, Train Loss: 0.6732, Train Accuracy: 0.5919, Test Loss: 0.6407, Test Accuracy: 0.6474
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 13.17it/s]
# Epoch 2/10, Train Loss: 0.6141, Train Accuracy: 0.6774, Test Loss: 0.6450, Test Accuracy: 0.5897
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 13.15it/s]
# Epoch 3/10, Train Loss: 0.6169, Train Accuracy: 0.6500, Test Loss: 0.6228, Test Accuracy: 0.6346
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 11.94it/s]
# Epoch 4/10, Train Loss: 0.6075, Train Accuracy: 0.6919, Test Loss: 0.5857, Test Accuracy: 0.6859
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 12.83it/s]
# Epoch 5/10, Train Loss: 0.6034, Train Accuracy: 0.6710, Test Loss: 0.5866, Test Accuracy: 0.6859
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 12.88it/s]
# Epoch 6/10, Train Loss: 0.5998, Train Accuracy: 0.6677, Test Loss: 0.5774, Test Accuracy: 0.7179
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 12.06it/s]
# Epoch 7/10, Train Loss: 0.5741, Train Accuracy: 0.6952, Test Loss: 0.6001, Test Accuracy: 0.6731
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 10.72it/s]
# Epoch 8/10, Train Loss: 0.5901, Train Accuracy: 0.7000, Test Loss: 0.5723, Test Accuracy: 0.7115
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 10.28it/s]
# Epoch 9/10, Train Loss: 0.5777, Train Accuracy: 0.7097, Test Loss: 0.5857, Test Accuracy: 0.6795
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 10.68it/s]
# Epoch 10/10, Train Loss: 0.5760, Train Accuracy: 0.7177, Test Loss: 0.5688, Test Accuracy: 0.6731
# Model saved to ./checkpoints/mlp_7_vs_9.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:02<00:00,  9.17it/s]
# Epoch 1/10, Train Loss: 0.5229, Train Accuracy: 0.7081, Test Loss: 0.4759, Test Accuracy: 0.7436
# Epoch 2/10: 100%|██████████| 20/20 [00:02<00:00,  8.54it/s]
# Epoch 2/10, Train Loss: 0.4139, Train Accuracy: 0.8097, Test Loss: 0.4585, Test Accuracy: 0.7564
# Epoch 3/10: 100%|██████████| 20/20 [00:02<00:00,  9.29it/s]
# Epoch 3/10, Train Loss: 0.4030, Train Accuracy: 0.8161, Test Loss: 0.4019, Test Accuracy: 0.8013
# Epoch 4/10: 100%|██████████| 20/20 [00:02<00:00,  8.90it/s]
# Epoch 4/10, Train Loss: 0.3655, Train Accuracy: 0.8274, Test Loss: 0.4221, Test Accuracy: 0.7885
# Epoch 5/10: 100%|██████████| 20/20 [00:02<00:00,  8.12it/s]
# Epoch 5/10, Train Loss: 0.3446, Train Accuracy: 0.8306, Test Loss: 0.4288, Test Accuracy: 0.7692
# Epoch 6/10: 100%|██████████| 20/20 [00:02<00:00,  7.75it/s]
# Epoch 6/10, Train Loss: 0.3148, Train Accuracy: 0.8581, Test Loss: 0.3510, Test Accuracy: 0.8269
# Epoch 7/10: 100%|██████████| 20/20 [00:02<00:00,  8.15it/s]
# Epoch 7/10, Train Loss: 0.2769, Train Accuracy: 0.8597, Test Loss: 0.3458, Test Accuracy: 0.8205
# Epoch 8/10: 100%|██████████| 20/20 [00:02<00:00,  8.43it/s]
# Epoch 8/10, Train Loss: 0.3057, Train Accuracy: 0.8629, Test Loss: 0.3460, Test Accuracy: 0.8205
# Epoch 9/10: 100%|██████████| 20/20 [00:02<00:00,  8.00it/s]
# Epoch 9/10, Train Loss: 0.2998, Train Accuracy: 0.8694, Test Loss: 0.3064, Test Accuracy: 0.8590
# Epoch 10/10: 100%|██████████| 20/20 [00:02<00:00,  8.02it/s]
# Epoch 10/10, Train Loss: 0.2965, Train Accuracy: 0.8661, Test Loss: 0.3463, Test Accuracy: 0.8205
# Model saved to ./checkpoints/cnn_7_vs_9.pth
# Training model for pair: 8 vs 9
# Training nn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 14.64it/s]
# Epoch 1/10, Train Loss: 0.6430, Train Accuracy: 0.6323, Test Loss: 0.6173, Test Accuracy: 0.6923
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 15.15it/s]
# Epoch 2/10, Train Loss: 0.5923, Train Accuracy: 0.6790, Test Loss: 0.5929, Test Accuracy: 0.6859
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 14.28it/s]
# Epoch 3/10, Train Loss: 0.5960, Train Accuracy: 0.6823, Test Loss: 0.5539, Test Accuracy: 0.7372
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 14.72it/s]
# Epoch 4/10, Train Loss: 0.5604, Train Accuracy: 0.7210, Test Loss: 0.5823, Test Accuracy: 0.6218
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 15.29it/s]
# Epoch 5/10, Train Loss: 0.5787, Train Accuracy: 0.7016, Test Loss: 0.5655, Test Accuracy: 0.7564
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 14.28it/s]
# Epoch 6/10, Train Loss: 0.5969, Train Accuracy: 0.6774, Test Loss: 0.5779, Test Accuracy: 0.7179
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 14.40it/s]
# Epoch 7/10, Train Loss: 0.5459, Train Accuracy: 0.7242, Test Loss: 0.6095, Test Accuracy: 0.6603
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 13.88it/s]
# Epoch 8/10, Train Loss: 0.5309, Train Accuracy: 0.7548, Test Loss: 0.5391, Test Accuracy: 0.7500
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 15.04it/s]
# Epoch 9/10, Train Loss: 0.5415, Train Accuracy: 0.7161, Test Loss: 0.5166, Test Accuracy: 0.7436
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 14.80it/s]
# Epoch 10/10, Train Loss: 0.5309, Train Accuracy: 0.7597, Test Loss: 0.5119, Test Accuracy: 0.7372
# Model saved to ./checkpoints/nn_8_vs_9.pth
# Training mlp model...
# Epoch 1/10: 100%|██████████| 20/20 [00:01<00:00, 11.79it/s]
# Epoch 1/10, Train Loss: 0.5591, Train Accuracy: 0.7306, Test Loss: 0.5472, Test Accuracy: 0.7372
# Epoch 2/10: 100%|██████████| 20/20 [00:01<00:00, 12.73it/s]
# Epoch 2/10, Train Loss: 0.5332, Train Accuracy: 0.7548, Test Loss: 0.5515, Test Accuracy: 0.7436
# Epoch 3/10: 100%|██████████| 20/20 [00:01<00:00, 11.87it/s]
# Epoch 3/10, Train Loss: 0.5262, Train Accuracy: 0.7435, Test Loss: 0.4995, Test Accuracy: 0.7179
# Epoch 4/10: 100%|██████████| 20/20 [00:01<00:00, 12.48it/s]
# Epoch 4/10, Train Loss: 0.5094, Train Accuracy: 0.7887, Test Loss: 0.5021, Test Accuracy: 0.7885
# Epoch 5/10: 100%|██████████| 20/20 [00:01<00:00, 12.03it/s]
# Epoch 5/10, Train Loss: 0.5182, Train Accuracy: 0.7597, Test Loss: 0.4815, Test Accuracy: 0.8013
# Epoch 6/10: 100%|██████████| 20/20 [00:01<00:00, 11.73it/s]
# Epoch 6/10, Train Loss: 0.4936, Train Accuracy: 0.7645, Test Loss: 0.4606, Test Accuracy: 0.8269
# Epoch 7/10: 100%|██████████| 20/20 [00:01<00:00, 12.30it/s]
# Epoch 7/10, Train Loss: 0.4895, Train Accuracy: 0.7839, Test Loss: 0.4674, Test Accuracy: 0.8205
# Epoch 8/10: 100%|██████████| 20/20 [00:01<00:00, 11.70it/s]
# Epoch 8/10, Train Loss: 0.4894, Train Accuracy: 0.7758, Test Loss: 0.4377, Test Accuracy: 0.8205
# Epoch 9/10: 100%|██████████| 20/20 [00:01<00:00, 11.62it/s]
# Epoch 9/10, Train Loss: 0.4767, Train Accuracy: 0.7855, Test Loss: 0.4799, Test Accuracy: 0.7756
# Epoch 10/10: 100%|██████████| 20/20 [00:01<00:00, 12.66it/s]
# Epoch 10/10, Train Loss: 0.4688, Train Accuracy: 0.8032, Test Loss: 0.4370, Test Accuracy: 0.8077
# Model saved to ./checkpoints/mlp_8_vs_9.pth
# Training cnn model...
# Epoch 1/10: 100%|██████████| 20/20 [00:02<00:00,  8.50it/s]
# Epoch 1/10, Train Loss: 0.6669, Train Accuracy: 0.7000, Test Loss: 0.4970, Test Accuracy: 0.7628
# Epoch 2/10: 100%|██████████| 20/20 [00:02<00:00,  8.12it/s]
# Epoch 2/10, Train Loss: 0.4688, Train Accuracy: 0.7839, Test Loss: 0.4383, Test Accuracy: 0.8269
# Epoch 3/10: 100%|██████████| 20/20 [00:02<00:00,  7.81it/s]
# Epoch 3/10, Train Loss: 0.4395, Train Accuracy: 0.8000, Test Loss: 0.3931, Test Accuracy: 0.8077
# Epoch 4/10: 100%|██████████| 20/20 [00:02<00:00,  8.35it/s]
# Epoch 4/10, Train Loss: 0.3518, Train Accuracy: 0.8403, Test Loss: 0.3721, Test Accuracy: 0.8205
# Epoch 5/10: 100%|██████████| 20/20 [00:02<00:00,  8.47it/s]
# Epoch 5/10, Train Loss: 0.3619, Train Accuracy: 0.8306, Test Loss: 0.3762, Test Accuracy: 0.8397
# Epoch 6/10: 100%|██████████| 20/20 [00:02<00:00,  8.77it/s]
# Epoch 6/10, Train Loss: 0.3381, Train Accuracy: 0.8452, Test Loss: 0.3009, Test Accuracy: 0.8718
# Epoch 7/10: 100%|██████████| 20/20 [00:02<00:00,  8.64it/s]
# Epoch 7/10, Train Loss: 0.3467, Train Accuracy: 0.8613, Test Loss: 0.3454, Test Accuracy: 0.8397
# Epoch 8/10: 100%|██████████| 20/20 [00:02<00:00,  8.84it/s]
# Epoch 8/10, Train Loss: 0.3148, Train Accuracy: 0.8629, Test Loss: 0.3080, Test Accuracy: 0.8654
# Epoch 9/10: 100%|██████████| 20/20 [00:02<00:00,  8.84it/s]
# Epoch 9/10, Train Loss: 0.2899, Train Accuracy: 0.8806, Test Loss: 0.3368, Test Accuracy: 0.8333
# Epoch 10/10: 100%|██████████| 20/20 [00:02<00:00,  8.46it/s]
# Epoch 10/10, Train Loss: 0.2824, Train Accuracy: 0.8677, Test Loss: 0.3648, Test Accuracy: 0.8077
# Model saved to ./checkpoints/cnn_8_vs_9.pth

# %% [markdown]
# Try to load the weights into the model and the confusion matrix for each model with every combination of numbers that you've obtained, as shown in the expected output.
#
#
# <details>
# <summary>
# <font size="3" color="orange">
# <b>Expected output</b>
# </font>
# </summary>
#
# - The output should resemble this, but not be identical
# This is just an example of NN. You should have three models: NN, MLP, and CNN, with one model per plot.
#
# ![image.png](https://github.com/Digital-Image-Processing-Laboratory/Image-Processing-Course-2025/blob/main/Lab4_NN-and-CNN/assets/09.png?raw=true)
#
# </details>

# %%
### START CODE HERE ###
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import math
import os

cols = 5
num_pairs = len(pair_digit)
rows = math.ceil(num_pairs / cols)

for name, model_instance in models.items():
    print(f"\n==== Evaluating all pairs for model: {name} ====")

    fig, axs = plt.subplots(rows, cols, figsize=(cols * 4, rows * 4))
    axs = axs.flatten()

    for idx, (class1, class2) in enumerate(pair_digit):
        print(f"Evaluating pair: {class1} vs {class2}")
        class_names = [str(class1), str(class2)]
        train_loader, test_loader = load_data(
            "./hand-writing", class_names
        )

        model = model_instance.to(device)
        checkpoint_path = f"./checkpoints/{name}_{class1}_vs_{class2}.pth"
        if not os.path.exists(checkpoint_path):
            print(f"Checkpoint {checkpoint_path} not found. Skipping.")
            axs[idx].axis("off")
            continue

        model.load_state_dict(torch.load(checkpoint_path, map_location=device))
        model.eval()

        all_predictions = []
        all_labels = []

        with torch.no_grad():
            for inputs, labels in test_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)
                
                unique_labels = torch.unique(labels)
                min_label = unique_labels.min()
                max_label = unique_labels.max()
                
                binary_labels = (labels == max_label).float()
                
                outputs = model(inputs)
                
                predictions = (outputs.squeeze() > 0.5).float()
                
                all_predictions.extend(predictions.cpu().numpy())
                all_labels.extend(binary_labels.cpu().numpy())

        # Convert to numpy arrays for easier handling
        all_predictions = np.array(all_predictions)
        all_labels = np.array(all_labels)
        
        # Create confusion matrix
        cm = confusion_matrix(all_labels, all_predictions, labels=[0, 1])

        # Display confusion matrix with original class names
        disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
        disp.plot(ax=axs[idx], cmap=plt.cm.Blues, colorbar=False)
        axs[idx].set_title(f"{class1} vs {class2}")

    # Turn off unused subplots
    for ax in axs[num_pairs:]:
        ax.axis("off")

    fig.suptitle(f"All Confusion Matrices for {name.upper()}", fontsize=18)
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])
    plt.show()

### END CODE HERE ###
# Out:
# ==== Evaluating all pairs for model: nn ====
# Evaluating pair: 0 vs 1
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 19
#      17 print(f"Evaluating pair: {class1} vs {class2}")
#      18 class_names = [str(class1), str(class2)]
# ---> 19 train_loader, test_loader = load_data(
#      20     "./hand-writing", class_names
#      21 )
#      23 model = model_instance.to(device)
#      24 checkpoint_path = f"./checkpoints/{name}_{class1}_vs_{class2}.pth"
#
# Cell In[2], line 14, in load_data(path, class_names)
#       1 def load_data(path, class_names):
#       2     ### START CODE HERE ###
#       3     transform = transforms.Compose(
#       4         [
#       5             transforms.Resize((32, 32)),
#    (...)     11         ]
#      12     )
# ---> 14     dataset = ImageFolder(path, transform=transform)
#      16     # filter dataset by class names
#      17     filtered_indices = [
#      18         i
#      19         for i, (_, label) in enumerate(dataset)
#      20         if dataset.classes[label] in class_names
#      21     ]
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\datasets\folder.py:328, in ImageFolder.__init__(self, root, transform, target_transform, loader, is_valid_file, allow_empty)
#     319 def __init__(
#     320     self,
#     321     root: Union[str, Path],
#    (...)    326     allow_empty: bool = False,
#     327 ):
# --> 328     super().__init__(
#     329         root,
#     330         loader,
#     331         IMG_EXTENSIONS if is_valid_file is None else None,
#     332         transform=transform,
#     333         target_transform=target_transform,
#     334         is_valid_file=is_valid_file,
#     335         allow_empty=allow_empty,
#     336     )
#     337     self.imgs = self.samples
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\datasets\folder.py:149, in DatasetFolder.__init__(self, root, loader, extensions, transform, target_transform, is_valid_file, allow_empty)
#     138 def __init__(
#     139     self,
#     140     root: Union[str, Path],
#    (...)    146     allow_empty: bool = False,
#     147 ) -> None:
#     148     super().__init__(root, transform=transform, target_transform=target_transform)
# --> 149     classes, class_to_idx = self.find_classes(self.root)
#     150     samples = self.make_dataset(
#     151         self.root,
#     152         class_to_idx=class_to_idx,
#    (...)    155         allow_empty=allow_empty,
#     156     )
#     158     self.loader = loader
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\datasets\folder.py:234, in DatasetFolder.find_classes(self, directory)
#     207 def find_classes(self, directory: Union[str, Path]) -> Tuple[List[str], Dict[str, int]]:
#     208     """Find the class folders in a dataset structured as follows::
#     209
#     210         directory/
#    (...)    232         (Tuple[List[str], Dict[str, int]]): List of all classes and dictionary mapping each class to an index.
#     233     """
# --> 234     return find_classes(directory)
#
# File c:\Users\PC\AppData\Local\Programs\Python\Python313\Lib\site-packages\torchvision\datasets\folder.py:41, in find_classes(directory)
#      36 def find_classes(directory: Union[str, Path]) -> Tuple[List[str], Dict[str, int]]:
#      37     """Finds the class folders in a dataset.
#      38
#      39     See :class:`DatasetFolder` for details.
#      40     """
# ---> 41     classes = sorted(entry.name for entry in os.scandir(directory) if entry.is_dir())
#      42     if not classes:
#      43         raise FileNotFoundError(f"Couldn't find any class folder in {directory}.")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: './hand-writing'

# %% [markdown]
# Questions
# 1. How does the performance of different models vary across different pairs of numbers in our dataset?
# 2. Can you identify the number pairs where the Neural Network model performs best and worst? Explain why the NN model is able/unable to classify these specific pairs based on the visualization of feature maps of each node in each layer.
# 3. Analyze and compare how MLP and CNN models perform on the dataset compared to the Neural Network model.  Identify scenarios where MLP and CNN outperform or underperform the NN. Explain the reasons behind these performance differences. Consider factors like the underlying structure of the data and the specific strengths of each model architecture.
# 4. According to your observations from questions 1-3, propose specific strategies to improve the performance of each model (NN, MLP, CNN) on this dataset. Consider factors such as data preprocessing, data augmentation, or potential changes to the model architecture itself. Justify your suggestions based on the strengths and limitations identified in the previous questions.

# %% [markdown]
# Question 1: Performance Variation Across Thai Number Pairs
# Thai Number Characteristics:
# Thai digits: ๐, ๑, ๒, ๓, ๔, ๕, ๖, ๗, ๘, ๙
# Unique features: More curves, loops, and artistic variations than Arabic numerals
# Cultural writing styles: Individual stroke patterns and traditional forms
# Expected Performance Patterns:
# Easy Pairs (High Accuracy >85%):
#
# ๐ vs ๑: Circle vs vertical line (similar to 0 vs 1)
# ๐ vs ๗: Closed loop vs angular shape
# ๑ vs ๘: Simple line vs complex curved structure
# ๒ vs ๖: Different orientations and stroke patterns
# Moderate Pairs (70-85% Accuracy):
#
# ๓ vs ๕: Both have curved elements but different structures
# ๔ vs ๗: Both angular but different orientations
# ๑ vs ๗: Vertical vs angular elements
# Difficult Pairs (60-80% Accuracy):
#
# ๖ vs ๙: Similar curved patterns, orientation-dependent
# ๒ vs ๓: Both have horizontal and curved elements
# ๔ vs ๙: Upper portions can be similar in handwriting

# %% [markdown]
# Question 2: NN Model Performance with Thai Numbers
# Best Performance Pairs for NN:
# Cultural Writing Variations:
# - Thai handwriting has more artistic freedom
# - Individual stroke styles vary significantly
# - Traditional vs modern writing forms
# - Pressure variations create different line thickness
#
# Feature Map Analysis for Thai Digits:
# - NN struggles with curved Thai characters (๓, ๕, ๖, ๘, ๙)
# - Better performance on simpler shapes (๐, ๑, ๗)
# - Cannot capture stroke order information
# - Misses cultural writing nuances
# ![image.png](attachment:image.png) best
#
# ![image-2.png](attachment:image-2.png) worst

# %% [markdown]
# Question 3: Model Comparison for Thai Handwriting
# CNN
# ✅ Better at detecting Thai curve patterns
# ✅ Can learn traditional stroke combinations
# ✅ Spatial relationships crucial for ๖ vs ๙ distinction
# ✅ Handles varying stroke thickness well
# ✅ Can detect loop closures in ๐, ๖, ๘, ๙
# 2D, Time Series
#
# MLP
# ✅ Can learn complex Thai character combinations
# ✅ Better than NN for curved pattern recognition
# ✅ Non-linear boundaries help with similar characters
# ✅ Can combine multiple stroke features

# %% [markdown]
# Question 4: Thai-Specific Improvement Strategies
# - NN struggles with spatial relationships, so adding edge features and gradient information helps it understand Thai stroke patterns better.
#
# - MLP can benefit from engineered features that capture Thai-specific patterns like curves, stroke density, and zonal characteristics.
#
# - CNN already handles spatial features well, but Thai characters need multi-scale processing, attention mechanisms, and conservative augmentation to preserve character integrity.
